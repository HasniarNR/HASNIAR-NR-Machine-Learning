# %% [markdown]
# # Ini adalah halaman teks

# %%
# menghitung jumlah dalam detik sehari
jumlah= 24

# %%
#menghitung jumlah dalam detik sehari
jumlah= 24

# %%
#menghitung rumus persegi panjang
panjang= 10
lebar= 5

# %%
nama_mhs1= "Budi"
nama_mhs2= "Andi"
print(nama_mhs1,)
print(nama_mhs2)
